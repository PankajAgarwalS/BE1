# %%
# !pip install ann_visualizer
# !pip install graphviz
# !pip install h5py

# %%
import pandas as pd
from sklearn import preprocessing

# %%
df = pd.read_csv('housepricedata.csv')
df
# Out:
#       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0        8450            7            5          856         2         1
# 1        9600            6            8         1262         2         0
# 2       11250            7            5          920         2         1
# 3        9550            7            5          756         1         0
# 4       14260            8            5         1145         2         1
# ...       ...          ...          ...          ...       ...       ...
# 1455     7917            6            5          953         2         1
# 1456    13175            6            6         1542         2         0
# 1457     9042            7            9         1152         2         0
# 1458     9717            5            6         1078         1         0
# 1459     9937            5            6         1256         1         1
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# 0                3             8           0         548                 1
# 1                3             6           1         460                 1
# 2                3             6           1         608                 1
# 3                3             7           1         642                 0
# 4                4             9           1         836                 1
# ...            ...           ...         ...         ...               ...
# 1455             3             7           1         460                 1
# 1456             3             7           2         500                 1
# 1457             4             9           2         252                 1
# 1458             2             5           0         240                 0
# 1459             3             6           0         276                 0
#
# [1460 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LotArea           1460 non-null   int64
#  1   OverallQual       1460 non-null   int64
#  2   OverallCond       1460 non-null   int64
#  3   TotalBsmtSF       1460 non-null   int64
#  4   FullBath          1460 non-null   int64
#  5   HalfBath          1460 non-null   int64
#  6   BedroomAbvGr      1460 non-null   int64
#  7   TotRmsAbvGrd      1460 non-null   int64
#  8   Fireplaces        1460 non-null   int64
#  9   GarageArea        1460 non-null   int64
#  10  AboveMedianPrice  1460 non-null   int64
# dtypes: int64(11)
# memory usage: 125.6 KB

# %%
df.describe()
# Out:
#              LotArea  OverallQual  OverallCond  TotalBsmtSF     FullBath  \
# count    1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean    10516.828082     6.099315     5.575342  1057.429452     1.565068
# std      9981.264932     1.382997     1.112799   438.705324     0.550916
# min      1300.000000     1.000000     1.000000     0.000000     0.000000
# 25%      7553.500000     5.000000     5.000000   795.750000     1.000000
# 50%      9478.500000     6.000000     5.000000   991.500000     2.000000
# 75%     11601.500000     7.000000     6.000000  1298.250000     2.000000
# max    215245.000000    10.000000     9.000000  6110.000000     3.000000
#
#           HalfBath  BedroomAbvGr  TotRmsAbvGrd   Fireplaces   GarageArea  \
# count  1460.000000   1460.000000   1460.000000  1460.000000  1460.000000
# mean      0.382877      2.866438      6.517808     0.613014   472.980137
# std       0.502885      0.815778      1.625393     0.644666   213.804841
# min       0.000000      0.000000      2.000000     0.000000     0.000000
# 25%       0.000000      2.000000      5.000000     0.000000   334.500000
# 50%       0.000000      3.000000      6.000000     1.000000   480.000000
# 75%       1.000000      3.000000      7.000000     1.000000   576.000000
# max       2.000000      8.000000     14.000000     3.000000  1418.000000
#
#        AboveMedianPrice
# count       1460.000000
# mean           0.498630
# std            0.500169
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            1.000000
# max            1.000000

# %%
df.isnull().sum()
# Out:
# LotArea             0
# OverallQual         0
# OverallCond         0
# TotalBsmtSF         0
# FullBath            0
# HalfBath            0
# BedroomAbvGr        0
# TotRmsAbvGrd        0
# Fireplaces          0
# GarageArea          0
# AboveMedianPrice    0
# dtype: int64

# %%
dataset = df.values

# %%
dataset
# Out:
# array([[ 8450,     7,     5, ...,     0,   548,     1],
#        [ 9600,     6,     8, ...,     1,   460,     1],
#        [11250,     7,     5, ...,     1,   608,     1],
#        ...,
#        [ 9042,     7,     9, ...,     2,   252,     1],
#        [ 9717,     5,     6, ...,     0,   240,     0],
#        [ 9937,     5,     6, ...,     0,   276,     0]], dtype=int64)

# %%
X = dataset[:,0:10]

# %%
Y = dataset[:,10]

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)

# %%
X_scale
# Out:
# array([[0.0334198 , 0.66666667, 0.5       , ..., 0.5       , 0.        ,
#         0.3864598 ],
#        [0.03879502, 0.55555556, 0.875     , ..., 0.33333333, 0.33333333,
#         0.32440056],
#        [0.04650728, 0.66666667, 0.5       , ..., 0.33333333, 0.33333333,
#         0.42877292],
#        ...,
#        [0.03618687, 0.66666667, 1.        , ..., 0.58333333, 0.66666667,
#         0.17771509],
#        [0.03934189, 0.44444444, 0.625     , ..., 0.25      , 0.        ,
#         0.16925247],
#        [0.04037019, 0.44444444, 0.625     , ..., 0.33333333, 0.        ,
#         0.19464034]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_val_and_test, Y_train, Y_val_and_test = train_test_split(X_scale, Y, test_size=0.3)

# %%
X_val, X_test, Y_val, Y_test = train_test_split(X_val_and_test, Y_val_and_test, test_size=0.5)

# %%
print(X_train.shape, X_val.shape, X_test.shape, Y_train.shape, Y_val.shape, Y_test.shape)
# Out:
# (1022, 10) (219, 10) (219, 10) (1022,) (219,) (219,)

# %%
from keras.models import Sequential
from keras.layers import Dense
model = Sequential([
    Dense(32, activation='relu', input_shape=(10,)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid'),
])

# %%
model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(X_train, Y_train,
          batch_size=32, epochs=100,
          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 5ms/step - loss: 0.6914 - accuracy: 0.4932 - val_loss: 0.6880 - val_accuracy: 0.5114
# Epoch 2/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6839 - accuracy: 0.4932 - val_loss: 0.6812 - val_accuracy: 0.5114
# Epoch 3/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6767 - accuracy: 0.4941 - val_loss: 0.6748 - val_accuracy: 0.5114
# Epoch 4/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6699 - accuracy: 0.4990 - val_loss: 0.6685 - val_accuracy: 0.5114
# Epoch 5/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6632 - accuracy: 0.5000 - val_loss: 0.6623 - val_accuracy: 0.5297
# Epoch 6/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6566 - accuracy: 0.5245 - val_loss: 0.6560 - val_accuracy: 0.5799
# Epoch 7/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6497 - accuracy: 0.6027 - val_loss: 0.6495 - val_accuracy: 0.6530
# Epoch 8/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6426 - accuracy: 0.7094 - val_loss: 0.6426 - val_accuracy: 0.6849
# Epoch 9/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6353 - accuracy: 0.7319 - val_loss: 0.6358 - val_accuracy: 0.6941
# Epoch 10/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6281 - accuracy: 0.7515 - val_loss: 0.6290 - val_accuracy: 0.7123
# Epoch 11/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6209 - accuracy: 0.7710 - val_loss: 0.6222 - val_accuracy: 0.7306
# Epoch 12/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6137 - accuracy: 0.7779 - val_loss: 0.6153 - val_accuracy: 0.7489
# Epoch 13/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6063 - accuracy: 0.7906 - val_loss: 0.6082 - val_accuracy: 0.7763
# Epoch 14/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5986 - accuracy: 0.7984 - val_loss: 0.6009 - val_accuracy: 0.7945
# Epoch 15/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5909 - accuracy: 0.8160 - val_loss: 0.5931 - val_accuracy: 0.8174
# Epoch 16/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5826 - accuracy: 0.8229 - val_loss: 0.5852 - val_accuracy: 0.8219
# Epoch 17/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5742 - accuracy: 0.8190 - val_loss: 0.5775 - val_accuracy: 0.8493
# Epoch 18/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5657 - accuracy: 0.8327 - val_loss: 0.5693 - val_accuracy: 0.8447
# Epoch 19/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5570 - accuracy: 0.8346 - val_loss: 0.5612 - val_accuracy: 0.8630
# Epoch 20/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5481 - accuracy: 0.8356 - val_loss: 0.5528 - val_accuracy: 0.8630
# Epoch 21/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.
# Epoch 68/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3074 - accuracy: 0.8767 - val_loss: 0.3103 - val_accuracy: 0.8813
# Epoch 69/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3057 - accuracy: 0.8796 - val_loss: 0.3086 - val_accuracy: 0.8904
# Epoch 70/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3041 - accuracy: 0.8806 - val_loss: 0.3084 - val_accuracy: 0.8813
# Epoch 71/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3035 - accuracy: 0.8796 - val_loss: 0.3057 - val_accuracy: 0.8904
# Epoch 72/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3022 - accuracy: 0.8796 - val_loss: 0.3044 - val_accuracy: 0.8904
# Epoch 73/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3012 - accuracy: 0.8777 - val_loss: 0.3031 - val_accuracy: 0.8813
# Epoch 74/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2999 - accuracy: 0.8806 - val_loss: 0.3016 - val_accuracy: 0.8904
# Epoch 75/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2987 - accuracy: 0.8836 - val_loss: 0.3005 - val_accuracy: 0.8950
# Epoch 76/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2978 - accuracy: 0.8816 - val_loss: 0.2992 - val_accuracy: 0.8950
# Epoch 77/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2965 - accuracy: 0.8826 - val_loss: 0.2984 - val_accuracy: 0.8950
# Epoch 78/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2954 - accuracy: 0.8816 - val_loss: 0.2968 - val_accuracy: 0.8858
# Epoch 79/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2948 - accuracy: 0.8826 - val_loss: 0.2957 - val_accuracy: 0.8950
# Epoch 80/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2939 - accuracy: 0.8826 - val_loss: 0.2948 - val_accuracy: 0.8950
# Epoch 81/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2930 - accuracy: 0.8845 - val_loss: 0.2936 - val_accuracy: 0.8950
# Epoch 82/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2923 - accuracy: 0.8806 - val_loss: 0.2925 - val_accuracy: 0.8950
# Epoch 83/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2901 - accuracy: 0.8816 - val_loss: 0.2916 - val_accuracy: 0.8950
# Epoch 84/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2900 - accuracy: 0.8855 - val_loss: 0.2915 - val_accuracy: 0.8995
# Epoch 85/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2893 - accuracy: 0.8806 - val_loss: 0.2908 - val_accuracy: 0.8995
# Epoch 86/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2882 - accuracy: 0.8845 - val_loss: 0.2891 - val_accuracy: 0.8995
# Epoch 87/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2881 - accuracy: 0.8845 - val_loss: 0.2878 - val_accuracy: 0.8950
# Epoch 88/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2869 - accuracy: 0.8855 - val_loss: 0.2872 - val_accuracy: 0.8995
# Epoch 89/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2867 - accuracy: 0.8826 - val_loss: 0.2863 - val_accuracy: 0.8950
# Epoch 90/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2855 - accuracy: 0.8836 - val_loss: 0.2853 - val_accuracy: 0.8950
# Epoch 91/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2844 - accuracy: 0.8845 - val_loss: 0.2849 - val_accuracy: 0.8995
# Epoch 92/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2839 - accuracy: 0.8865 - val_loss: 0.2836 - val_accuracy: 0.8950
# Epoch 93/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2833 - accuracy: 0.8855 - val_loss: 0.2831 - val_accuracy: 0.8995
# Epoch 94/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2823 - accuracy: 0.8836 - val_loss: 0.2824 - val_accuracy: 0.8995
# Epoch 95/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2821 - accuracy: 0.8885 - val_loss: 0.2813 - val_accuracy: 0.8950
# Epoch 96/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2817 - accuracy: 0.8845 - val_loss: 0.2812 - val_accuracy: 0.8995
# Epoch 97/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2803 - accuracy: 0.8855 - val_loss: 0.2801 - val_accuracy: 0.8995
# Epoch 98/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2804 - accuracy: 0.8875 - val_loss: 0.2790 - val_accuracy: 0.8995
# Epoch 99/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2792 - accuracy: 0.8885 - val_loss: 0.2786 - val_accuracy: 0.8995
# Epoch 100/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2789 - accuracy: 0.8845 - val_loss: 0.2778 - val_accuracy: 0.8995

# %%
model.evaluate(X_test, Y_test)[1]
# Out:
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3004 - accuracy: 0.8767
# 0.8767123222351074

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
    
# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
from ann_visualizer.visualize import ann_viz;
from keras.models import model_from_json
import numpy
# fix random seed for reproducibility
numpy.random.seed(7)
# load json and create model
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
model2 = model_from_json(loaded_model_json)

# load weights into new model
model.load_weights("model.h5")
ann_viz(model2, title="Artificial Neural network - Model Visualization")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[100], line 14
#      12 # load weights into new model
#      13 model.load_weights("model.h5")
# ---> 14 ann_viz(model2, title="Artificial Neural network - Model Visualization")
#
# File ~\anaconda3\lib\site-packages\ann_visualizer\visualize.py:44, in ann_viz(model, view, filename, title)
#      42 input_layer = int(str(layer.input_shape).split(",")[1][1:-1]);
#      43 hidden_layers_nr += 1;
# ---> 44 if (type(layer) == keras.layers.core.Dense):
#      45     hidden_layers.append(int(str(layer.output_shape).split(",")[1][1:-1]));
#      46     layer_types.append("Dense");
#
# AttributeError: module 'keras.layers' has no attribute 'core'
