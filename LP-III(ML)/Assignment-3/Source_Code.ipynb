# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set()

import os

# %% [markdown]
# ## Loading Dataset

# %%
df = pd.read_csv("Churn_Modelling.csv")

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %% [markdown]
# ### Removal of Column 'Surname' since Neural Networks need numeric columns only

# %%
df.drop(['Surname'], axis=1, inplace=True)
df
# Out:
#       RowNumber  CustomerId  CreditScore Geography  Gender  Age  Tenure  \
# 0             1    15634602          619    France  Female   42       2
# 1             2    15647311          608     Spain  Female   41       1
# 2             3    15619304          502    France  Female   42       8
# 3             4    15701354          699    France  Female   39       1
# 4             5    15737888          850     Spain  Female   43       2
# ...         ...         ...          ...       ...     ...  ...     ...
# 9995       9996    15606229          771    France    Male   39       5
# 9996       9997    15569892          516    France    Male   35      10
# 9997       9998    15584532          709    France  Female   36       7
# 9998       9999    15682355          772   Germany    Male   42       3
# 9999      10000    15628319          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0          0.00              1          1               1        101348.88
# 1      83807.86              1          0               1        112542.58
# 2     159660.80              3          1               0        113931.57
# 3          0.00              2          0               0         93826.63
# 4     125510.82              1          1               1         79084.10
# ...         ...            ...        ...             ...              ...
# 9995       0.00              2          1               0         96270.64
# 9996   57369.61              1          1               1        101699.77
# 9997       0.00              1          0               1         42085.58
# 9998   75075.31              2          1               0         92888.52
# 9999  130142.79              1          1               0         38190.78
#
#       Exited
# 0          1
# 1          0
# 2          1
# 3          0
# 4          0
# ...      ...
# 9995       0
# 9996       0
# 9997       1
# 9998       1
# 9999       0
#
# [10000 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(2)
# memory usage: 1015.8+ KB

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %% [markdown]
# **Finding Missing Values**

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.nunique()
# Out:
# RowNumber          10000
# CustomerId         10000
# CreditScore          460
# Geography              3
# Gender                 2
# Age                   70
# Tenure                11
# Balance             6382
# NumOfProducts          4
# HasCrCard              2
# IsActiveMember         2
# EstimatedSalary     9999
# Exited                 2
# dtype: int64

# %% [markdown]
# **Separating Predictor class from Prediciton Class**

# %%
X_columns = df.columns.tolist()[2:12]
y_columns = df.columns.tolist()[-1:]
print(f'All columns: {df.columns.tolist()}')
print()
print(f'X values: {X_columns}')
print()
print(f'y values: {y_columns}')
# Out:
# All columns: ['RowNumber', 'CustomerId', 'CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited']
#
# X values: ['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary']
#
# y values: ['Exited']

# %% [markdown]
# **Here**<br>
# X = Predictor Values<br>
# Y = Resultant/Prediction class

# %%
X = df[X_columns].values # Credit Score through Estimated Salary
y = df[y_columns].values # Exited

# %% [markdown]
# ## Label Encoding

# %% [markdown]
# Chaning String value to Numeric

# %%
from sklearn.preprocessing import LabelEncoder

print(X[:8,2], '\nAfter Label Encoding')
label_X_gender_encoder = LabelEncoder()
X[:,2] = label_X_gender_encoder.fit_transform(X[:,2])
print(X[:8,2])
# Out:
# ['Female' 'Female' 'Female' 'Female' 'Female' 'Male' 'Male' 'Female']
# After Label Encoding
# [0 0 0 0 0 1 1 0]

# %% [markdown]
# France  - 0 <br>
# Germany - 1<br>
# Spain   - 2<br>

# %%
print(X[:8,3], '\nAfter Label Encoding')
label_X_gender_encoder = LabelEncoder()
X[:,3] = label_X_gender_encoder.fit_transform(X[:,3])
print(X[:8,3])
# Out:
# [42 41 42 39 43 44 50 29]
# After Label Encoding
# [24 23 24 21 25 26 32 11]

# %% [markdown]
# Female - 0<br>
# Male - 1

# %% [markdown]
# ## Standard Scaling and OneHotEncoding

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline


pipeline = Pipeline(
    [('Categorizer', ColumnTransformer(
         [ # Gender
          ("Gender Label encoder", OneHotEncoder(categories='auto', drop='first'), [2]),
           # Geography
          ("Geography One Hot", OneHotEncoder(categories='auto', drop='first'), [1])
         ], remainder='passthrough', n_jobs=1)),
     # Standard Scaler for the classifier
    ('Normalizer', StandardScaler())
    ])

# %%
X = pipeline.fit_transform(X)

# %% [markdown]
# ## Train-Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 0)

# %%
print(f'training shapes: {X_train.shape}, {y_train.shape}')
print(f'testing shapes: {X_test.shape}, {y_test.shape}')
# Out:
# training shapes: (8000, 11), (8000, 1)
# testing shapes: (2000, 11), (2000, 1)

# %% [markdown]
# ## Modelling

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
# Initializing the ANN
classifier = Sequential()

# %%
# This adds the input layer (by specifying input dimension) AND the first hidden layer (units)
classifier.add(Dense(6, activation = 'relu', input_shape = (X_train.shape[1], )))
classifier.add(Dropout(rate=0.1))

# %%
# Adding the second hidden layer
# Notice that we do not need to specify input dim. 
classifier.add(Dense(6, activation = 'relu')) 
classifier.add(Dropout(rate=0.1))

# %%
# Adding the output layer
# Notice that we do not need to specify input dim. 
# we have an output of 1 node, which is the the desired dimensions of our output (stay with the bank or not)
# We use the sigmoid because we want probability outcomes
classifier.add(Dense(1, activation = 'sigmoid'))

# %%
classifier.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 6)                 72
#
#  dropout (Dropout)           (None, 6)                 0
#
#  dense_1 (Dense)             (None, 6)                 42
#
#  dropout_1 (Dropout)         (None, 6)                 0
#
#  dense_2 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 121 (484.00 Byte)
# Trainable params: 121 (484.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
classifier.compile(optimizer='adam', loss = 'binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## Model Training

# %%
history = classifier.fit(X_train, y_train, batch_size=32, epochs=200, validation_split=0.1, verbose=2)
# Out:
# Epoch 1/200
# 225/225 - 1s - loss: 0.6417 - accuracy: 0.6712 - val_loss: 0.5175 - val_accuracy: 0.7887 - 989ms/epoch - 4ms/step
# Epoch 2/200
# 225/225 - 0s - loss: 0.5084 - accuracy: 0.7894 - val_loss: 0.4652 - val_accuracy: 0.7950 - 232ms/epoch - 1ms/step
# Epoch 3/200
# 225/225 - 0s - loss: 0.4794 - accuracy: 0.7949 - val_loss: 0.4461 - val_accuracy: 0.7962 - 218ms/epoch - 970us/step
# Epoch 4/200
# 225/225 - 0s - loss: 0.4667 - accuracy: 0.7960 - val_loss: 0.4331 - val_accuracy: 0.7962 - 227ms/epoch - 1ms/step
# Epoch 5/200
# 225/225 - 0s - loss: 0.4547 - accuracy: 0.7985 - val_loss: 0.4226 - val_accuracy: 0.8050 - 231ms/epoch - 1ms/step
# Epoch 6/200
# 225/225 - 0s - loss: 0.4451 - accuracy: 0.8072 - val_loss: 0.4117 - val_accuracy: 0.8075 - 275ms/epoch - 1ms/step
# Epoch 7/200
# 225/225 - 0s - loss: 0.4390 - accuracy: 0.8107 - val_loss: 0.4042 - val_accuracy: 0.8238 - 243ms/epoch - 1ms/step
# Epoch 8/200
# 225/225 - 0s - loss: 0.4308 - accuracy: 0.8181 - val_loss: 0.3981 - val_accuracy: 0.8288 - 230ms/epoch - 1ms/step
# Epoch 9/200
# 225/225 - 0s - loss: 0.4316 - accuracy: 0.8164 - val_loss: 0.3929 - val_accuracy: 0.8313 - 226ms/epoch - 1ms/step
# Epoch 10/200
# 225/225 - 0s - loss: 0.4227 - accuracy: 0.8254 - val_loss: 0.3873 - val_accuracy: 0.8363 - 228ms/epoch - 1ms/step
# Epoch 11/200
# 225/225 - 0s - loss: 0.4149 - accuracy: 0.8254 - val_loss: 0.3818 - val_accuracy: 0.8425 - 217ms/epoch - 965us/step
# Epoch 12/200
# 225/225 - 0s - loss: 0.4093 - accuracy: 0.8289 - val_loss: 0.3762 - val_accuracy: 0.8450 - 216ms/epoch - 961us/step
# Epoch 13/200
# 225/225 - 0s - loss: 0.4017 - accuracy: 0.8306 - val_loss: 0.3708 - val_accuracy: 0.8450 - 220ms/epoch - 979us/step
# Epoch 14/200
# 225/225 - 0s - loss: 0.3990 - accuracy: 0.8350 - val_loss: 0.3664 - val_accuracy: 0.8462 - 215ms/epoch - 956us/step
# Epoch 15/200
# 225/225 - 0s - loss: 0.3933 - accuracy: 0.8386 - val_loss: 0.3624 - val_accuracy: 0.8462 - 226ms/epoch - 1ms/step
# Epoch 16/200
# 225/225 - 0s - loss: 0.3875 - accuracy: 0.8379 - val_loss: 0.3581 - val_accuracy: 0.8487 - 227ms/epoch - 1ms/step
# Epoch 17/200
# 225/225 - 0s - loss: 0.3829 - accuracy: 0.8438 - val_loss: 0.3554 - val_accuracy: 0.8512 - 226ms/epoch - 1ms/step
# Epoch 18/200
# 225/225 - 0s - loss: 0.3827 - accuracy: 0.8410 - val_loss: 0.3540 - val_accuracy: 0.8500 - 222ms/epoch - 986us/step
# Epoch 19/200
# 225/225 - 0s - loss: 0.3772 - accuracy: 0.8450 - val_loss: 0.3522 - val_accuracy: 0.8500 - 221ms/epoch - 983us/step
# Epoch 20/200
# 225/225 - 0s - loss: 0.3774 - accuracy: 0.8436 - val_loss: 0.3498 - val_accuracy: 0.8562 - 238ms/epoch - 1ms/step
# Epoch 21/200
# 225/225 - 0s - loss: 0.3790 - accuracy: 0.8408 - val_loss: 0.3498 - val_accuracy: 0.8512 - 240ms/epoch - 1ms/step
# Epoch 22/200
# 225/225 - 0s - loss: 0.3812 - accuracy: 0.8421 - val_loss: 0.3482 - val_accuracy: 0.8562 - 229ms/epoch - 1ms/step
# Epoch 23/200
# 225/225 - 0s - loss: 0.3798 - accuracy: 0.8394 - val_loss: 0.3478 - val_accuracy: 0.8562 - 230ms/epoch - 1ms/step
# Epoch 24/200
# 225/225 - 0s - loss: 0.3762 - accuracy: 0.8460 - val_loss: 0.3461 - val_accuracy: 0.8587 - 240ms/epoch - 1ms/step
# Epoch 25/200
# 225/225 - 0s - loss: 0.3778 - accuracy: 0.8429 - val_loss: 0.3467 - val_accuracy: 0.8550 - 224ms/epoch - 996us/step
# Epoch 26/200
# 225/225 - 0s - loss: 0.3773 - accuracy: 0.8483 - val_loss: 0.3437 - val_accuracy: 0.8600 - 226ms/epoch - 1ms/step
# Epoch 27/200
# 225/225 - 0s - loss: 0.3748 - accuracy: 0.8485 - val_loss: 0.3438 - val_accuracy: 0.8625 - 225ms/epoch - 1ms/step
# Epoch 28/200
# 225/225 - 0s - loss: 0.3754 - accuracy: 0.8456 - val_loss: 0.3428 - val_accuracy: 0.8612 - 244ms/epoch - 1ms/step
# Epoch 29/200
# 225/225 - 0s - loss: 0.3789 - accuracy: 0.8465 - val_loss: 0.3428 - val_accuracy: 0.8625 - 228ms/epoch - 1ms/step
# Epoch 30/200
# 225/225 - 0s - loss: 0.3764 - accuracy: 0.8446 - val_loss: 0.3424 - val_accuracy: 0.8637 - 232ms/epoch - 1ms/step
# Epoch 31/200
# 225/225 - 0s - loss: 0.3760 - accuracy: 0.8447 - val_loss: 0.3422 - val_accuracy: 0.8587 - 366ms/epoch - 2ms/step
# Epoch 32/200
# 225/225 - 0s - loss: 0.3713 - accuracy: 0.8474 - val_loss: 0.3419 - val_accuracy: 0.8650 - 329ms/epoch - 1ms/step
# Epoch 33/200
# 225/225 - 0s - loss: 0.3711 - accuracy: 0.8504 - val_loss: 0.3403 - val_accuracy: 0.8662 - 267ms/epoch - 1ms/step
# Epoch 34/200
# 225/225 - 0s - loss: 0.3741 - accuracy: 0.8460 - val_loss: 0.3412 - val_accuracy: 0.8662 - 267ms/epoch - 1ms/step
# Epoch 35/200
# 225/225 - 0s - loss: 0.3737 - accuracy: 0.8469 - val_loss: 0.3395 - val_accuracy: 0.8650 - 281ms/epoch - 1ms/step
# Epoch 36/200
# 225/225 - 0s - loss: 0.3727 - accuracy: 0.8464 - val_loss: 0.3403 - val_accuracy: 0.8675 - 234ms/epoch - 1ms/step
# Epoch 37/200
# 225/225 - 0s - loss: 0.3700 - accuracy: 0.8504 - val_loss: 0.3394 - val_accuracy: 0.8662 - 273ms/epoch - 1ms/step
# Epoch 38/200
# 225/225 - 0s - loss: 0.3732 - accuracy: 0.8464 - val_loss: 0.3401 - val_accuracy: 0.8662 - 233ms/epoch - 1ms/step
# Epoch 39/200
# 225/225 - 0s - loss: 0.3715 - accuracy: 0.8494 - val_loss: 0.3383 - val_accuracy: 0.8675 - 234ms/epoch - 1ms/step
# Epoch 40/200
# 225/225 - 0s - loss: 0.3684 - accuracy: 0.8500 - val_loss: 0.3380 - val_accuracy: 0.8675 - 234ms/epoch - 1ms/step
# Epoch 41/200
# 225/225 - 0s - loss: 0.3697 - accuracy: 0.8493 - val_loss: 0.3385 - val_accuracy: 0.8625 - 227ms/epoch - 1ms/step
# Epoch 42/200
# 225/225 - 0s - loss: 0.3754 - accuracy: 0.8492 - val_loss: 0.3377 - val_accuracy: 0.8650 - 231ms/epoch - 1ms/step
# Epoch 43/200
# 225/225 - 0s - loss: 0.3687 - accuracy: 0.8496 - val_loss: 0.3391 - val_accuracy: 0.8637 - 224ms/epoch - 996us/step
# Epoch 44/200
# 225/225 - 0s - loss: 0.3724 - accuracy: 0.8469 - val_loss: 0.3381 - val_accuracy: 0.8675 - 246ms/epoch - 1ms/step
# Epoch 45/200
# 225/225 - 0s - loss: 0.3733 - accuracy: 0.8494 - val_loss: 0.3399 - val_accuracy: 0.8587 - 225ms/epoch - 1ms/step
# Epoch 46/200
# 225/225 - 0s - loss: 0.3680 - accuracy: 0.8519 - val_loss: 0.3384 - val_accuracy: 0.8637 - 213ms/epoch - 948us/step
# Epoch 47/200
# 225/225 - 0s - loss: 0.3687 - accuracy: 0.8492 - val_loss: 0.3373 - val_accuracy: 0.8612 - 220ms/epoch - 979us/step
# Epoch 48/200
# 225/225 - 0s - loss: 0.3726 - accuracy: 0.8494 - val_loss: 0.3381 - val_accuracy: 0.8637 - 228ms/epoch - 1ms/step
# Epoch 49/200
# 225/225 - 0s - loss: 0.3689 - accuracy: 0.8496 - val_loss: 0.3372 - val_accuracy: 0.8625 - 222ms/epoch - 988us/step
# Epoch 50/200
# 225/225 - 0s - loss: 0.3694 - accuracy: 0.8500 - val_loss: 0.3369 - val_accuracy: 0.8612 - 216ms/epoch - 961us/step
# Epoch 51/200
# 225/225 - 0s - loss: 0.3651 - accuracy: 0.8504 - val_loss: 0.3357 - val_accuracy: 0.8625 - 219ms/epoch - 974us/step
# Epoch 52/200
# 225/225 - 0s - loss: 0
ms/step
# Epoch 178/200
# 225/225 - 0s - loss: 0.3651 - accuracy: 0.8472 - val_loss: 0.3268 - val_accuracy: 0.8650 - 244ms/epoch - 1ms/step
# Epoch 179/200
# 225/225 - 0s - loss: 0.3587 - accuracy: 0.8517 - val_loss: 0.3251 - val_accuracy: 0.8650 - 253ms/epoch - 1ms/step
# Epoch 180/200
# 225/225 - 0s - loss: 0.3609 - accuracy: 0.8514 - val_loss: 0.3261 - val_accuracy: 0.8675 - 251ms/epoch - 1ms/step
# Epoch 181/200
# 225/225 - 0s - loss: 0.3647 - accuracy: 0.8503 - val_loss: 0.3268 - val_accuracy: 0.8675 - 242ms/epoch - 1ms/step
# Epoch 182/200
# 225/225 - 0s - loss: 0.3628 - accuracy: 0.8489 - val_loss: 0.3256 - val_accuracy: 0.8675 - 247ms/epoch - 1ms/step
# Epoch 183/200
# 225/225 - 0s - loss: 0.3642 - accuracy: 0.8476 - val_loss: 0.3254 - val_accuracy: 0.8687 - 251ms/epoch - 1ms/step
# Epoch 184/200
# 225/225 - 0s - loss: 0.3651 - accuracy: 0.8517 - val_loss: 0.3245 - val_accuracy: 0.8675 - 254ms/epoch - 1ms/step
# Epoch 185/200
# 225/225 - 0s - loss: 0.3605 - accuracy: 0.8512 - val_loss: 0.3250 - val_accuracy: 0.8662 - 248ms/epoch - 1ms/step
# Epoch 186/200
# 225/225 - 0s - loss: 0.3634 - accuracy: 0.8482 - val_loss: 0.3247 - val_accuracy: 0.8675 - 250ms/epoch - 1ms/step
# Epoch 187/200
# 225/225 - 0s - loss: 0.3613 - accuracy: 0.8479 - val_loss: 0.3245 - val_accuracy: 0.8662 - 249ms/epoch - 1ms/step
# Epoch 188/200
# 225/225 - 0s - loss: 0.3580 - accuracy: 0.8486 - val_loss: 0.3253 - val_accuracy: 0.8675 - 242ms/epoch - 1ms/step
# Epoch 189/200
# 225/225 - 0s - loss: 0.3578 - accuracy: 0.8475 - val_loss: 0.3259 - val_accuracy: 0.8650 - 306ms/epoch - 1ms/step
# Epoch 190/200
# 225/225 - 0s - loss: 0.3592 - accuracy: 0.8517 - val_loss: 0.3256 - val_accuracy: 0.8662 - 247ms/epoch - 1ms/step
# Epoch 191/200
# 225/225 - 0s - loss: 0.3591 - accuracy: 0.8506 - val_loss: 0.3268 - val_accuracy: 0.8662 - 275ms/epoch - 1ms/step
# Epoch 192/200
# 225/225 - 0s - loss: 0.3575 - accuracy: 0.8521 - val_loss: 0.3246 - val_accuracy: 0.8662 - 257ms/epoch - 1ms/step
# Epoch 193/200
# 225/225 - 0s - loss: 0.3594 - accuracy: 0.8501 - val_loss: 0.3253 - val_accuracy: 0.8662 - 240ms/epoch - 1ms/step
# Epoch 194/200
# 225/225 - 0s - loss: 0.3559 - accuracy: 0.8540 - val_loss: 0.3261 - val_accuracy: 0.8650 - 247ms/epoch - 1ms/step
# Epoch 195/200
# 225/225 - 0s - loss: 0.3595 - accuracy: 0.8511 - val_loss: 0.3251 - val_accuracy: 0.8700 - 221ms/epoch - 982us/step
# Epoch 196/200
# 225/225 - 0s - loss: 0.3596 - accuracy: 0.8526 - val_loss: 0.3263 - val_accuracy: 0.8712 - 219ms/epoch - 974us/step
# Epoch 197/200
# 225/225 - 0s - loss: 0.3637 - accuracy: 0.8500 - val_loss: 0.3273 - val_accuracy: 0.8637 - 211ms/epoch - 939us/step
# Epoch 198/200
# 225/225 - 0s - loss: 0.3620 - accuracy: 0.8481 - val_loss: 0.3259 - val_accuracy: 0.8662 - 218ms/epoch - 970us/step
# Epoch 199/200
# 225/225 - 0s - loss: 0.3597 - accuracy: 0.8528 - val_loss: 0.3259 - val_accuracy: 0.8712 - 206ms/epoch - 916us/step
# Epoch 200/200
# 225/225 - 0s - loss: 0.3595 - accuracy: 0.8518 - val_loss: 0.3271 - val_accuracy: 0.8675 - 216ms/epoch - 961us/step

# %% [markdown]
# ## Model Evaluation

# %%
plt.plot(np.array(history.history['accuracy']) * 100)
plt.plot(np.array(history.history['val_accuracy']) * 100)
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train', 'validation'])
plt.title('Accuracy over epochs')
plt.show()

# %% [markdown]
# ## Predicting on Test Class

# %%
y_pred = classifier.predict(X_test)
print(y_pred[:5])
# Out:
# 63/63 [==============================] - 0s 678us/step
# [[0.26223442]
#  [0.253474  ]
#  [0.16978945]
#  [0.07267887]
#  [0.10104129]]

# %% [markdown]
# To use the confusion Matrix, we need to convert the probabilities that a customer will leave the bank into the form true or false. So we will use the cutoff value 0.5 to indicate whether they are likely to exit or not.

# %%
y_pred = (y_pred > 0.5).astype(int)
print(y_pred[:5])
# Out:
# [[0]
#  [0]
#  [0]
#  [0]
#  [0]]

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[1537   58]
#  [ 211  194]]

# %% [markdown]
# **Values are represented as**
# |             | Predicted: No | Predicted: Yes |
# |------------ |:-------------:|:--------------:|
# | Actual: No  | 1537          | 58             |
# | Actual: Yes | 211           | 194            |

# %% [markdown]
# ## Model Accuracy

# %%
print (((cm[0][0]+cm[1][1])*100)/(len(y_test)), '% of testing data was classified correctly')
# Out:
# 86.55 % of testing data was classified correctly
